# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.tri as tri

# %% [markdown]
# ### 01 网络图
# tri.Triangulation() 展示点与点的相邻关系
# plt.triplot()将上面的关系展示再地图上

# %%
data = np.random.rand(100, 2)
triangles = tri.Triangulation(data[:,0], data[:,1])
plt.triplot(triangles)
plt.show()
