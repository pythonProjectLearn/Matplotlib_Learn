# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### 01 虽然只设置了4种颜色，但是会循环调用
# 注意color_set必须是元组

# %%
values = np.random.rand(8)
color_set = ('.00', '.25', '.50', '.75')
plt.pie(values, colors = color_set)
plt.show()
